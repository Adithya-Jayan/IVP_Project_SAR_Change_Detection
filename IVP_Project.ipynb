# %%
import os
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
#Mount Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Data = "/content/drive/My Drive/Datasets/ChangeDetection/CD_DNN/Bern-SAR/"

# %%
for dirname, _, filenames in os.walk(Data):
  print(filenames)
# Out:
# ['changed_map.bmp', 'difference_image.bmp', 'im1.bmp', 'im2.bmp', 'im3.bmp']

# %%
Images = [Data + x for x in filenames]

# %%
print(Images)
# Out:
# ['/content/drive/My Drive/Datasets/ChangeDetection/CD_DNN/Bern-SAR/changed_map.bmp', '/content/drive/My Drive/Datasets/ChangeDetection/CD_DNN/Bern-SAR/difference_image.bmp', '/content/drive/My Drive/Datasets/ChangeDetection/CD_DNN/Bern-SAR/im1.bmp', '/content/drive/My Drive/Datasets/ChangeDetection/CD_DNN/Bern-SAR/im2.bmp', '/content/drive/My Drive/Datasets/ChangeDetection/CD_DNN/Bern-SAR/im3.bmp']

# %%
Images = [plt.imread(x) for x in Images]

# %%
for i in range(len(Images)):
  plt.figure()
  plt.imshow(Images[i])

# %%
plt.figure()
plt.rcParams["figure.figsize"]=(10,10)
plt.imshow(Images[3]-Images[2])

# %%
cv2_imshow(Images[3]-Images[2])
# Out:
# <PIL.Image.Image image mode=RGB size=301x301 at 0x7F9ADB8E9400>

# %%
(Images[1]).shape
# Out:
# (301, 301, 3)
